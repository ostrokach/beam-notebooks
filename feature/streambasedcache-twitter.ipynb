# %% [markdown]
# # FileBasedCache - bi-directional storage primitives for Apache Beam

# %% [markdown]
# ## Install dependencies

# %%
# !sudo apt-get -yqq install libsnappy-dev

# %%
# !pip install -q python-snappy Faker

# %%
# !pip install "git+https://github.com/ostrokach/beam.git@feature/filebasedcache#egg=apache_beam[gcp]&subdirectory=sdks/python"
# Out:
# Requirement already satisfied: apache_beam[gcp] from git+https://github.com/ostrokach/beam.git@feature/filebasedcache#egg=apache_beam[gcp]&subdirectory=sdks/python in /usr/local/lib/python2.7/dist-packages (2.15.0.dev0)
# Requirement already satisfied: pyyaml<4.0.0,>=3.12 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.13)
# Requirement already satisfied: avro<2.0.0,>=1.8.1; python_version < "3.0" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.9.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (2.5.6)
# Requirement already satisfied: pyarrow<0.14.0,>=0.11.1; python_version >= "3.0" or platform_system != "Windows" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.13.0)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (2.0.0)
# Requirement already satisfied: future<1.0.0,>=0.16.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.16.0)
# Requirement already satisfied: fastavro<0.22,>=0.21.4 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.21.24)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.8.0)
# Requirement already satisfied: dill<0.2.10,>=0.2.9 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.2.9)
# Requirement already satisfied: grpcio<2,>=1.8 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.15.0)
# Requirement already satisfied: typing<3.7.0,>=3.6.0; python_version < "3.5.0" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.6.6)
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (2018.9)
# Requirement already satisfied: protobuf<4,>=3.5.0.post1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.7.1)
# Requirement already satisfied: httplib2<=0.12.0,>=0.8 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.11.3)
# Requirement already satisfied: pydot<1.3,>=1.2.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.2.4)
# Requirement already satisfied: oauth2client<4,>=2.0.1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.0.0)
# Requirement already satisfied: futures<4.0.0,>=3.2.0; python_version < "3.0" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.2.0)
# Requirement already satisfied: pyvcf<0.7.0,>=0.6.8; python_version < "3.0" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.6.8)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.7)
# Requirement already satisfied: google-apitools<0.5.29,>=0.5.28; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.5.28)
# Requirement already satisfied: proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0; python_version < "3.0" and extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.90.4)
# Requirement already satisfied: google-cloud-bigquery<1.7.0,>=1.6.0; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.6.1)
# Requirement already satisfied: cachetools<4,>=3.1.0; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.1.1)
# Requirement already satisfied: google-cloud-pubsub<0.40.0,>=0.39.0; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.39.1)
# Requirement already satisfied: google-cloud-core<0.30.0,>=0.28.1; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.29.1)
# Requirement already satisfied: googledatastore<7.1,>=7.0.1; python_version < "3.0" and extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (7.0.2)
# Requirement already satisfied: google-cloud-bigtable<0.33.0,>=0.31.1; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.32.2)
# Requirement already satisfied: google-cloud-datastore<1.8.0,>=1.7.1; extra == "gcp" in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.7.4)
# Requirement already satisfied: docopt in /usr/local/lib/python2.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (0.6.2)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python2.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2.21.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (1.12.0)
# Requirement already satisfied: enum34>=1.1.6; python_version < "3.4" in /usr/local/lib/python2.7/dist-packages (from pyarrow<0.14.0,>=0.11.1; python_version >= "3.0" or platform_system != "Windows"->apache_beam[gcp]) (1.1.6)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python2.7/dist-packages (from pyarrow<0.14.0,>=0.11.1; python_version >= "3.0" or platform_system != "Windows"->apache_beam[gcp]) (1.16.4)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock<3.0.0,>=1.0.1->apache_beam[gcp]) (1.0.2)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock<3.0.0,>=1.0.1->apache_beam[gcp]) (5.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf<4,>=3.5.0.post1->apache_beam[gcp]) (41.0.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python2.7/dist-packages (from pydot<1.3,>=1.2.0->apache_beam[gcp]) (2.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (4.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (0.2.5)
# Requirement already satisfied: fasteners>=0.14 in /usr/local/lib/python2.7/dist-packages (from google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache_beam[gcp]) (0.15)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.2 in /usr/local/lib/python2.7/dist-packages (from proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0; python_version < "3.0" and extra == "gcp"->apache_beam[gcp]) (1.6.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.0.0 in /usr/local/lib/python2.7/dist-packages (from google-cloud-bigquery<1.7.0,>=1.6.0; extra == "gcp"->apache_beam[gcp]) (1.11.1)
# Requirement already satisfied: google-resumable-media>=0.2.1 in /usr/local/lib/python2.7/dist-packages (from google-cloud-bigquery<1.7.0,>=1.6.0; extra == "gcp"->apache_beam[gcp]) (0.3.2)
# Requirement already satisfied: grpc-google-iam-v1<0.12dev,>=0.11.4 in /usr/local/lib/python2.7/dist-packages (from google-cloud-pubsub<0.40.0,>=0.39.0; extra == "gcp"->apache_beam[gcp]) (0.11.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2.8)
# Requirement already satisfied: monotonic>=0.1 in /usr/local/lib/python2.7/dist-packages (from fasteners>=0.14->google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache_beam[gcp]) (1.5)
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /usr/local/lib/python2.7/dist-packages (from google-api-core<2.0.0dev,>=1.0.0->google-cloud-bigquery<1.7.0,>=1.6.0; extra == "gcp"->apache_beam[gcp]) (1.4.2)

# %% [markdown]
# ## Imports

# %%
import copy
import itertools
import logging
import os
import tempfile
import uuid
import pickle

import apache_beam as beam
import fastavro
import numpy as np
import pandas as pd
import tqdm
from apache_beam.io.filesystems import FileSystems
from apache_beam.options.pipeline_options import (GoogleCloudOptions,
                                                  PipelineOptions)
from apache_beam.runners.direct.direct_runner import BundleBasedDirectRunner
from apache_beam.runners.interactive import caching
from apache_beam.transforms.ptransform import ptransform_fn
from faker import Faker

# %% [markdown]
# ## Parameters

# %%
temp_location = tempfile.mkdtemp(prefix="beam-dev-")

cache_location = tempfile.mkdtemp(dir=temp_location, prefix="cache-")

temp_location, cache_location
# Out:
# ('/tmp/beam-dev-ZxP49F', '/tmp/beam-dev-ZxP49F/cache-35ocoU')

# %%
options = PipelineOptions(runner="direct", temp_location=temp_location)
options.display_data()
# Out:
# WARNING:root:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-fe76e8aa-10b6-4841-bbd6-806e49e017a2.json']
# {'runner': 'direct', 'temp_location': '/tmp/beam-dev-ZxP49F'}

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Generate a dataset of fake people profiles

# %%
try:
    with open("fake_people.pkl", "rb") as f:
        fake_people = pickle.load(f)
except IOError:
    fake = Faker(42)
    fake_people = [fake.profile(fields=None, sex=None) for _ in tqdm.tqdm_notebook(range(10000))]
    with open("fake_people.pkl", "wb") as f:
        pickle.dump(fake_people,f )
# Out:
# HBox(children=(IntProgress(value=0, max=10000), HTML(value=u'')))

# %%
fake_people[0]
# Out:
# {'address': u'399 William Groves\nMorganhaven, WA 49272',
#  'birthdate': datetime.date(1962, 4, 24),
#  'blood_group': 'B+',
#  'company': u'Thomas, Cruz and Small',
#  'current_location': (Decimal('-62.4194185'), Decimal('131.920989')),
#  'job': 'Ecologist',
#  'mail': u'goodmananna@gmail.com',
#  'name': u'Steven Watkins',
#  'residence': u'394 Rachel Mews\nBeardmouth, AR 30354',
#  'sex': 'M',
#  'ssn': u'475-46-1888',
#  'username': u'smiller',
#  'website': [u'http://schultz.net/']}

# %% [markdown]
# ## Analyse data

# %% [markdown]
# ### Create a PCollection cache
#
# Convert the generated dataset into a `PCollection` which can be accessed from within a Beam pipeline.

# %%
input_cache = caching.SafeTextBasedCache(FileSystems.join(cache_location, "fake_people"), if_exists="overwrite")
input_cache.write(fake_people)

# %%
next(input_cache.read())
# Out:
# {'address': u'399 William Groves\nMorganhaven, WA 49272',
#  'birthdate': datetime.date(1962, 4, 24),
#  'blood_group': 'B+',
#  'company': u'Thomas, Cruz and Small',
#  'current_location': (Decimal('-62.4194185'), Decimal('131.920989')),
#  'job': 'Ecologist',
#  'mail': u'goodmananna@gmail.com',
#  'name': u'Steven Watkins',
#  'residence': u'394 Rachel Mews\nBeardmouth, AR 30354',
#  'sex': 'M',
#  'ssn': u'475-46-1888',
#  'username': u'smiller',
#  'website': [u'http://schultz.net/']}

# %% [markdown]
# ### Validate the PCollection cache

# %%
# Make sure we have 10_000 fake profiles, as expected
temp = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.combiners.Count.Globally()
        | temp.writer()
    )

assert next(temp.read()) == 10000

# %% [markdown]
# ### Select people with duplicate usernames

# %%
# Make sure every username is distinct
temp = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | "Extract username" >> beam.WithKeys(lambda e: e["username"])
        | "Group people by username" >> beam.GroupByKey(lambda e: e)
        | beam.Values()
        | "Select groups with at least two people" >> beam.Filter(lambda vs: len(vs) >= 2)
        | "Ungroup" >> beam.FlatMap(lambda gp: [e for e in gp])
        | temp.writer()
    )

# %%
pd.DataFrame(temp.read()).sort_values("username")
# Out:
#                                                address  ...                                            website
# 450  6141 Gibbs Gateway Suite 312\nNorth Jessicavie...  ...  [http://www.pace-jordan.com/, https://cervante...
# 449                          USNV Austin\nFPO AE 27822  ...  [https://www.salazar.net/, http://www.herrera....
# 873   46860 Henderson Ports\nWest Meganmouth, IL 14690  ...                         [https://www.shelton.biz/]
# 872         994 Watson Wells\nDominguezmouth, MD 10842  ...  [https://www.goodwin-gonzalez.com/, http://joh...
# 651  41789 Dawson Lights Apt. 198\nOwensberg, OR 21880  ...  [http://parker.com/, https://www.torres-rivera...
# 650           7319 Julie Mission\nGarciaberg, NV 25150  ...                          [https://www.kaiser.com/]
# 119       30352 Jonathan Land\nHernandeztown, CT 55694  ...  [https://hunt.com/, https://klein.net/, https:...
# 118        86395 William Vista\nKaitlynmouth, NJ 83811  ...  [http://www.griffin.com/, http://smith.org/, h...
# 35          8058 Parker Orchard\nDanielmouth, WV 58356  ...  [https://huffman-hodge.com/, https://www.allen...
# 36    789 Smith Hollow Suite 406\nMillerland, NE 07759  ...  [https://www.whitney-wang.net/, https://www.jo...
# 652  0127 Chambers Parks Suite 959\nAlvarezberg, NY...  ...                    [https://www.rogers-owen.info/]
# 654  74632 Fischer Mill Suite 601\nPennyfort, OR 75146  ...  [https://www.scott.com/, http://www.thompson.c...
# 653          960 Myers Islands\nWest Timothy, NJ 84468  ...  [http://cole-hernandez.com/, http://johnson.co...
# 717           77196 Wright Island\nPort Fred, MT 83371  ...  [http://www.campbell-durham.biz/, http://gross...
# 716                145 Rush Forks\nJuliaview, ME 84869  ...                                [https://barr.biz/]
# 670  9667 Taylor Crossroad Suite 986\nEricbury, NE ...  ...   [https://moreno.com/, https://www.shepherd.org/]
# 672     1863 Burns Camp Apt. 566\nLake Damon, WA 36381  ...  [http://www.bryant.info/, https://www.gray.net...
# 671   517 Long Knoll Apt. 000\nNew Mackenzie, IA 17830  ...  [http://cook-klein.com/, https://alexander.biz...
# 863      77012 Kimberly Station\nVanessaberg, NV 37243  ...  [https://arnold-white.com/, https://sullivan.c...
# 865    421 Rodney Parkways\nPort Katelyntown, AZ 57160  ...                            [http://www.weber.biz/]
# 864             6902 Palmer Lakes\nBrownberg, MS 83588  ...                          [https://www.duncan.org/]
# 348        82789 Nicole Pike\nPort Brettside, LA 84515  ...  [https://west-fowler.com/, https://www.sampson...
# 347       74906 Christopher Ford\nNguyenfort, LA 78805  ...  [https://smith-duran.com/, http://fox.com/, ht...
# 582       0453 Kevin Inlet Suite 570\nAnnton, IL 40419  ...  [http://www.lee.biz/, https://johnson-jackson....
# 581  87856 Louis Turnpike Suite 628\nThomasstad, FL...  ...                      [https://www.mcgee-long.org/]
# 792         68777 Miller Course\nNew Phillip, ND 69577  ...  [http://www.cowan-davenport.org/, http://www.b...
# 791      4564 Bell Roads\nLake Christineberg, IA 66800  ...  [https://le-green.com/, http://www.navarro-esp...
# 790   1299 Dennis Village\nNorth Stevenmouth, NV 54107  ...  [https://mcgrath-flowers.biz/, http://www.pere...
# 796  404 Ashley Station Apt. 785\nCarpenterstad, MD...  ...                         [http://woods-smith.info/]
# 795           29365 Eric Flat\nThompsonburgh, FL 87048  ...                [http://www.fisher-dickerson.info/]
# ..                                                 ...  ...                                                ...
# 254           00648 Kelly Hollow\nWilsonside, WI 13096  ...  [https://www.smith.net/, https://mccarty.com/,...
# 255        2653 William Stravenue\nWardburgh, IA 45153  ...  [https://www.bray.com/, http://www.blackwell.c...
# 253          8958 Wood Ridge\nSouth Danielle, MT 44425  ...                [https://www.burton-williams.info/]
# 614  146 Sparks Lock Apt. 333\nPort Kimberlyfort, C...  ...  [http://www.evans-butler.biz/, http://potter.c...
# 615          62787 Catherine Row\nJohnnyport, NY 39614  ...  [https://www.berg-berg.biz/, https://cherry.co...
# 616  584 Greene Summit Suite 039\nKristenstad, TN 0...  ...  [https://scott-brown.com/, https://www.gardner...
# 420           503 Bradley Estate\nWrightport, WI 13830  ...  [https://www.stevens-wright.info/, http://nguy...
# 421  1320 Campbell Streets Suite 708\nNorth Maurice...  ...                           [https://www.lynch.biz/]
# 418                   PSC 3560, Box 0618\nAPO AP 39168  ...                   [https://martinez-stephens.com/]
# 419               328 Nixon View\nTeresaside, WV 92580  ...  [https://rosales.net/, http://www.fisher-bryan...
# 522       5341 Samantha Cliff\nNorth Richard, CT 07864  ...           [https://www.lee.com/, http://barr.com/]
# 521                   PSC 5074, Box 1537\nAPO AA 64904  ...          [https://williams.org/, http://webb.net/]
# 519        9492 Cassidy Motorway\nLake Maria, UT 81589  ...                      [http://www.green-evans.com/]
# 520            167 Hannah Port\nVeronicafurt, AZ 12827  ...                   [https://stanley-williams.info/]
# 488       00805 Destiny Island\nNew Kimberly, NJ 42589  ...                         [http://www.williams.org/]
# 489  194 Fritz Land Suite 969\nNorth Edwardberg, DC...  ...                    [https://williams-jacobs.info/]
# 442  493 Johnson Radial Apt. 679\nLake Teresa, VA 0...  ...  [https://adams.com/, http://martinez.com/, htt...
# 441        96728 Russell Mission\nDavidville, NY 94603  ...      [https://www.caldwell.com/, http://bell.com/]
# 620        944 Fitzgerald Fords\nBryanthaven, KY 37080  ...  [http://www.rios-hall.com/, http://www.rogers-...
# 619  39821 Emily Plaza Suite 580\nNew Zachary, TX 9...  ...  [https://johnson.com/, https://www.sanders-wel...
# 843  0904 Karen Summit Suite 831\nPort Jacqueline, ...  ...                              [https://walker.net/]
# 842         53869 Felicia Path\nLake Zachary, SD 24872  ...  [http://hernandez-yoder.info/, http://price-ro...
# 648     925 Christopher Highway\nConradmouth, NH 89048  ...  [https://www.jones.info/, http://ryan.info/, h...
# 649  081 Michael Port Suite 112\nAustinchester, ID ...  ...            [https://small.com/, http://green.biz/]
# 908  40726 Baker Pike Suite 961\nSandraburgh, MN 65339  ...  [http://www.middleton-whitney.com/, https://gi...
# 909       73677 Sean Throughway\nSouth Donna, AZ 27379  ...                         [https://gay-salazar.com/]
# 105  7829 Daniel Heights Apt. 234\nSouth Jayfort, N...  ...  [http://nichols.biz/, http://smith.com/, http:...
# 104  56731 Charlene Ridge Suite 071\nNew Emmahaven,...  ...  [http://www.leonard.info/, http://bentley-berg...
# 45                    PSC 4656, Box 2756\nAPO AP 23705  ...      [https://www.cruz.info/, http://www.fox.org/]
# 44   356 Mendoza Cliffs Suite 279\nPort Bethany, OR...  ...  [http://wall.com/, http://www.phillips-abbott....
#
# [1014 rows x 13 columns]

# %% [markdown]
# ### Find most popular occupations

# %% [markdown]
# Select top 10 most popular occupations in the `> 30` age group.

# %%
def calculate_age(birthdate):
    import datetime
    td = datetime.date.today() - birthdate
    return int(round(td.days // 365.25))

def add_age_colum(element):
    element["age"] = calculate_age(element["birthdate"])
    return element

# %%
most_popular_occupations = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "most_popular_occupations"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(add_age_colum)
        | beam.Filter(lambda e: e["age"] > 30)
        | beam.Map(lambda e: (e["job"], e))
        | beam.combiners.Count.PerKey()
        | beam.combiners.Top.Of(10, key=lambda x: x[1])
        | most_popular_occupations.writer()
    )

# %%
next(most_popular_occupations.read())
# Out:
# [('Management consultant', 27),
#  ('Personal assistant', 22),
#  ('Music tutor', 21),
#  ('Warden/ranger', 21),
#  ('Homeopath', 21),
#  ('Fast food restaurant manager', 20),
#  ('Art gallery manager', 20),
#  ('Games developer', 20),
#  ('Production engineer', 19),
#  ('Product/process development scientist', 19)]

# %% [markdown]
# ## Process and export data

# %%
def normalize_data(element):
    return {
        "username": element["username"],
        "first_name": element["name"].split()[0],
        "last_name": " ".join(element["name"].split()[1:]),
        "mail": element["name"],
        "job": element["name"],
        "company": element["name"],
        "age": calculate_age(element["birthdate"]),
        "current_location_lat": float(element["current_location"][0]),
        "current_location_long": float(element["current_location"][1]),
        "website": element["website"] or [],
    }

normalize_data(element)
# Out:
# {'age': 64,
#  'company': u'Gary Lewis',
#  'current_location_lat': 28.4744555,
#  'current_location_long': -77.483937,
#  'first_name': u'Gary',
#  'job': u'Gary Lewis',
#  'last_name': u'Lewis',
#  'mail': u'Gary Lewis',
#  'username': u'raymondparker',
#  'website': [u'http://www.rivera.info/',
#   u'http://kelly-mcdowell.com/',
#   u'https://white-yu.com/',
#   u'http://brown.biz/']}

# %%
avro_schema = fastavro.parse_schema({
    "namespace": "example.avro",
    "name": "User",
    "type": "record",
    "fields": [
        {"name": "username", "type": "string"},
        {"name": "first_name", "type": "string"},
        {"name": "last_name", "type": "string"},
        {"name": "mail", "type": "string"},
        {"name": "job", "type": "string"},
        {"name": "company", "type": "string"},
        {"name": "age", "type": "int"},
        {"name": "current_location_lat", "type": "double"},
        {"name": "current_location_long", "type": "double"},
        {"name": "website", "type": {"type": "array", "items": "string"}},
    ],
})
avro_schema
# Out:
# {'__fastavro_parsed': True,
#  'fields': [{'name': 'username', 'type': 'string'},
#   {'name': 'first_name', 'type': 'string'},
#   {'name': 'last_name', 'type': 'string'},
#   {'name': 'mail', 'type': 'string'},
#   {'name': 'job', 'type': 'string'},
#   {'name': 'company', 'type': 'string'},
#   {'name': 'age', 'type': 'int'},
#   {'name': 'current_location_lat', 'type': 'double'},
#   {'name': 'current_location_long', 'type': 'double'},
#   {'name': 'website', 'type': {'items': 'string', 'type': 'array'}}],
#  'name': 'example.avro.User',
#  'type': 'record'}

# %%
output = caching.AvroBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite", schema=avro_schema,
    use_fastavro=True,
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(normalize_data)
        | output.writer()
    )

# %%
next(output.read())
# Out:
# {u'age': 57,
#  u'company': u'Steven Watkins',
#  u'current_location_lat': -62.4194185,
#  u'current_location_long': 131.920989,
#  u'first_name': u'Steven',
#  u'job': u'Steven Watkins',
#  u'last_name': u'Watkins',
#  u'mail': u'Steven Watkins',
#  u'username': u'smiller',
#  u'website': [u'http://schultz.net/']}

# %% [markdown]
# ## Write SQL queries against the result

# %% [markdown]
# ### Google Cloud

# %% [markdown]
# ## Export data to Google Cloud

# %%
#@title Google Cloud Project Info { display-mode: "form" }
project_id = "asdfdsf" #@param {type:"string"}
gcs_temp_location = "" #@param {type:"string"}

# %%
from google.colab import auth
auth.authenticate_user()

# %%
gcs_output = caching.AvroBasedCache(
    FileSystems.join(gcs_temp_location, "filebasedcache-output"), if_exists="overwrite",
    schema=avro_schema, use_fastavro=True)

gcs_output.write(output.read())

# %%
next(gcs_output.read())
# Out:
# IOErrorTraceback (most recent call last)
# <ipython-input-311-362a8e5ab806> in <module>()
# ----> 1 next(gcs_output.read())
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/interactive/caching/filebasedcache.pyc in read(self, **reader_kwargs)
#      96
#      97   def read(self, **reader_kwargs):
# ---> 98     source = self.reader(**reader_kwargs)._source
#      99     range_tracker = source.get_range_tracker(None, None)
#     100     for element in source.read(range_tracker):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/interactive/caching/filebasedcache.pyc in reader(self, **reader_kwargs)
#      83     }
#      84     kwargs.update(reader_kwargs)
# ---> 85     return self._reader_class(self._file_pattern, **kwargs)
#      86
#      87   def writer(self):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/avroio.pyc in __init__(self, file_pattern, min_bundle_size, validate, use_fastavro)
#     163         min_bundle_size,
#     164         validate=validate,
# --> 165         use_fastavro=use_fastavro
#     166     )
#     167
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/avroio.pyc in _create_avro_source(file_pattern, min_bundle_size, validate, use_fastavro)
#     315           validate=validate
#     316       ) \
# --> 317       if use_fastavro \
#     318       else \
#     319       _AvroSource(
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/filebasedsource.pyc in __init__(self, file_pattern, min_bundle_size, compression_type, splittable, validate)
#     119     self._splittable = splittable
#     120     if validate and file_pattern.is_accessible():
# --> 121       self._validate()
#     122
#     123   def display_data(self):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/options/value_provider.pyc in _f(self, *args, **kwargs)
#     135         if not obj.is_accessible():
#     136           raise error.RuntimeValueProviderError('%s not accessible' % obj)
# --> 137       return fnc(self, *args, **kwargs)
#     138     return _f
#     139   return _check_accessible
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/filebasedsource.pyc in _validate(self)
#     179     if len(match_result.metadata_list) <= 0:
#     180       raise IOError(
# --> 181           'No files found based on the file pattern %s' % pattern)
#     182
#     183   def split(
#
# IOError: No files found based on the file pattern filebasedcache-output*

# %% [markdown]
# ### Query data using BigQuery

# %%
from google.cloud import bigquery

# %%
options = PipelineOptions(runner="direct", temp_location=gc_temp_location, staging_location=gsc_temp_location, project=project_id)
options.display_data()
# Out:
# WARNING:root:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-fe76e8aa-10b6-4841-bbd6-806e49e017a2.json']
# {'project': 'strokach-playground',
#  'runner': 'direct',
#  'staging_location': 'gs://strokach/temp',
#  'temp_location': 'gs://strokach/temp'}

# %%
FileSystems.mkdirs(gsc_temp_location)
FileSystems.mkdirs(FileSystems.join(gsc_temp_location, "filebasedcache-demo"))

# %%
gcs_output = caching.AvroBasedCache(
    FileSystems.join(gcs_temp_location), if_exists="overwrite",
    schema=avro_schema, use_fastavro=True)

# gce_output.write(output.read())


with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(normalize_data)
        | output.writer()
    )
# Out:
# BeamIOErrorTraceback (most recent call last)
# <ipython-input-230-ca645d693763> in <module>()
#      11         | input_cache.reader()
#      12         | beam.Map(normalize_data)
# ---> 13         | gce_output.writer()
#      14     )
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/pipeline.pyc in __exit__(self, exc_type, exc_val, exc_tb)
#     424   def __exit__(self, exc_type, exc_val, exc_tb):
#     425     if not exc_type:
# --> 426       self.run().wait_until_finish()
#     427
#     428   def visit(self, visitor):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/pipeline.pyc in run(self, test_runner_api)
#     404           self.to_runner_api(use_fake_coders=True),
#     405           self.runner,
# --> 406           self._options).run(False)
#     407
#     408     if self._options.view_as(TypeOptions).runtime_type_check:
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/pipeline.pyc in run(self, test_runner_api)
#     417       finally:
#     418         shutil.rmtree(tmpdir)
# --> 419     return self.runner.run_pipeline(self, self._options)
#     420
#     421   def __enter__(self):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/direct/direct_runner.pyc in run_pipeline(self, pipeline, options)
#     126       runner = BundleBasedDirectRunner()
#     127
# --> 128     return runner.run_pipeline(pipeline, options)
#     129
#     130
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in run_pipeline(self, pipeline, options)
#     292
#     293     self._latest_run_result = self.run_via_runner_api(pipeline.to_runner_api(
# --> 294         default_environment=self._default_environment))
#     295     return self._latest_run_result
#     296
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in run_via_runner_api(self, pipeline_proto)
#     299     # TODO(pabloem, BEAM-7514): Create a watermark manager (that has access to
#     300     #   the teststream (if any), and all the stages).
# --> 301     return self.run_stages(stage_context, stages)
#     302
#     303   @contextlib.contextmanager
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in run_stages(self, stage_context, stages)
#     381               stage,
#     382               pcoll_buffers,
# --> 383               stage_context.safe_coders)
#     384           metrics_by_stage[stage.name] = stage_results.process_bundle.metrics
#     385           monitoring_infos_by_stage[stage.name] = (
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in _run_stage(self, worker_handler_factory, pipeline_components, stage, pcoll_buffers, safe_coders)
#     653         self._progress_frequency)
#     654
# --> 655     result, splits = bundle_manager.process_bundle(data_input, data_output)
#     656
#     657     def input_for(ptransform_id, input_id):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in process_bundle(self, inputs, expected_outputs)
#    1469         process_bundle=beam_fn_api_pb2.ProcessBundleRequest(
#    1470             process_bundle_descriptor_reference=self._bundle_descriptor.id))
# -> 1471     result_future = self._controller.control_handler.push(process_bundle_req)
#    1472
#    1473     split_results = []
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/portability/fn_api_runner.pyc in push(self, request)
#     988       self._uid_counter += 1
#     989       request.instruction_id = 'control_%s' % self._uid_counter
# --> 990     response = self.worker.do_instruction(request)
#     991     return ControlFuture(request.instruction_id, response)
#     992
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/sdk_worker.pyc in do_instruction(self, request)
#     340       # E.g. if register is set, this will call self.register(request.register))
#     341       return getattr(self, request_type)(getattr(request, request_type),
# --> 342                                          request.instruction_id)
#     343     else:
#     344       raise NotImplementedError
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/sdk_worker.pyc in process_bundle(self, request, instruction_id)
#     366         with self.maybe_profile(instruction_id):
#     367           delayed_applications, requests_finalization = (
# --> 368               bundle_processor.process_bundle(instruction_id))
#     369           response = beam_fn_api_pb2.InstructionResponse(
#     370               instruction_id=instruction_id,
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/bundle_processor.pyc in process_bundle(self, instruction_id)
#     591             instruction_id, expected_transforms):
#     592           input_op_by_transform_id[
# --> 593               data.ptransform_id].process_encoded(data.data)
#     594
#     595       # Finish all operations.
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/bundle_processor.pyc in process_encoded(self, encoded_windowed_values)
#     141       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     142           input_stream, True)
# --> 143       self.output(decoded_value)
#     144
#     145   def try_split(self, fraction_of_remainder, total_buffer_size):
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/operations.so in apache_beam.runners.worker.operations.Operation.output()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/operations.so in apache_beam.runners.worker.operations.Operation.output()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/operations.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/operations.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/worker/operations.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.DoFnRunner.receive()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/runners/common.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/iobase.pyc in <genexpr>(***failed resolving arguments***)
#    1083   if outputs:
#    1084     return (
# -> 1085         window.TimestampedValue(v, timestamp.MAX_TIMESTAMP) for v in outputs)
#    1086
#    1087
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/filebasedsink.pyc in finalize_write(self, init_result, writer_results, unused_pre_finalize_results)
#     271
#     272     src_files, dst_files, delete_files, num_skipped = (
# --> 273         self._check_state_for_finalize_write(writer_results, num_shards))
#     274     num_skipped += len(delete_files)
#     275     FileSystems.delete(delete_files)
#
# /usr/local/lib/python2.7/dist-packages/apache_beam/io/filebasedsink.pyc in _check_state_for_finalize_write(self, writer_results, num_shards)
#     249       if not src_exists and not dst_exists:
#     250         raise BeamIOError('src and dst files do not exist. src: %s, dst: %s' % (
# --> 251             src, dst))
#     252       if not src_exists and dst_exists:
#     253         logging.debug('src: %s -> dst: %s already renamed, skipping', src, dst)
#
# BeamIOError: src and dst files do not exist. src: gs://strokach/beam-temp-temp-000-aba0dc9c948811e9bd880242ac1c0002/8da83071-c718-4eba-9bb0-7052cd0687dd.temp-000, dst: gs://strokach/temp-000-00000-of-00001 with exceptions None [while running 'WriteToAvro/Write/WriteImpl/FinalizeWrite'] with exceptions None

# %%
gcs_output._existing_file_paths()
# Out:
# [u'gs://strokach/temp/filebasedcache-output-001']

# %%
# Configure the external data source and query job
table_id = 'fake_people'
external_config = bigquery.ExternalConfig('AVRO')
external_config.source_uris = gcs_output._existing_file_paths()

# external_config.schema = [
#     bigquery.SchemaField('name', 'STRING'),
#     bigquery.SchemaField('post_abbr', 'STRING')
# ]
# external_config.options.skip_leading_rows = 1  # optionally skip header row

# %%
external_config.to_api_repr()
# Out:
# {'sourceFormat': 'AVRO',
#  'sourceUris': [u'gs://strokach/temp/filebasedcache-output-001']}

# %%
client = bigquery.Client(project=project_id)
# Out:
# WARNING:google.auth._default:No project ID could be determined. Consider running `gcloud config set project` or setting the GOOGLE_CLOUD_PROJECT environment variable

# %%
# Example query to find states starting with 'W'
sql_query = """
SELECT *
FROM `{table_id}`
WHERE AGE = (
    SELECT MAX(age)
    FROM `{table_id}`
)
""".format(table_id=table_id)

job_config = bigquery.QueryJobConfig()
job_config.table_definitions = {table_id: external_config}

query_job = client.query(sql_query, job_config=job_config)

# %%
query_job.to_dataframe()
# Out:
#            username  ...                                            website
# 0    georgemorrison  ...  [https://wilson-casey.info/, https://palmer.com/]
# 1    smithchristine  ...  [http://mcknight-lawrence.net/, https://fitzge...
# 2       martinlaura  ...  [http://www.robinson-walker.com/, http://www.b...
# 3       walterslisa  ...   [http://www.stout.org/, http://burke-jones.com/]
# 4   alexanderoneill  ...  [http://wolf.info/, https://reed.net/, https:/...
# 5        palmerdana  ...      [https://www.brooks.com/, http://spence.com/]
# 6     christopher87  ...  [https://mcpherson-brown.info/, http://www.col...
# 7        angelaroth  ...  [https://cunningham.biz/, http://moore.com/, h...
# 8        jamesriley  ...  [http://www.torres.com/, http://www.harris.com...
# 9       alexandra66  ...  [http://smith.org/, https://guerra.com/, https...
# 10     dennisjoshua  ...    [http://mitchell.com/, https://www.butler.com/]
# 11    nicolejohnson  ...  [https://roberts.com/, https://rush.net/, http...
# 12        lancewolf  ...  [http://santiago.com/, https://www.carpenter.b...
# 13         moyeramy  ...             [http://davis.com/, https://bush.com/]
# 14          brian96  ...  [http://www.alexander.com/, http://rice.com/, ...
# 15          wmercer  ...  [https://www.banks.info/, http://www.warren.or...
# 16   fernandomoreno  ...  [https://james.net/, http://www.lopez.net/, ht...
# 17       mdominguez  ...  [http://rangel-bowers.info/, https://www.rober...
# 18          brian89  ...  [https://www.luna.biz/, https://fitzpatrick.com/]
# 19       ehendricks  ...  [https://kelly-meyers.com/, https://lewis.com/...
# 20        heather56  ...  [http://www.gibson.com/, http://www.ramos-bass...
# 21     smithwilliam  ...                 [http://www.christian-nguyen.net/]
# 22        ypeterson  ...  [https://www.lynch-thompson.com/, https://king...
# 23         dwayne92  ...  [http://www.poole.net/, https://reid-boyd.com/...
# 24           oadams  ...  [https://robbins-lopez.com/, https://www.lewis...
# 25        jessica86  ...  [https://www.fleming-sutton.com/, https://carr...
# 26        bakermary  ...                              [http://mcbride.com/]
# 27      stantonjohn  ...  [https://rogers-rodriguez.com/, http://woodard...
# 28     johnsondavid  ...  [https://www.scott-davis.com/, https://www.tho...
# 29         denise12  ...                       [https://www.macdonald.com/]
# ..              ...  ...                                                ...
# 59           udavis  ...  [http://hickman.net/, https://www.petersen.com...
# 60        eduardo58  ...                    [http://www.black-carter.info/]
# 61      jonesrachel  ...    [http://www.weber.com/, https://wilkinson.com/]
# 62        fcastillo  ...  [https://brooks.net/, http://carr.info/, http:...
# 63      kleinkendra  ...  [http://powell.com/, https://www.garrett.com/,...
# 64       brianadams  ...  [http://fisher-cross.com/, https://gibson-hunt...
# 65      ruizmatthew  ...  [https://www.compton.com/, http://young-ramire...
# 66   aguirrekatrina  ...  [http://wilson-mejia.com/, http://brown-marsh....
# 67           owatts  ...                             [https://roberts.com/]
# 68      christina99  ...                           [https://www.wells.com/]
# 69      sharptrevor  ...  [https://blake-hunter.com/, http://www.green.i...
# 70      rachelboyer  ...  [http://www.raymond.net/, https://martin.org/,...
# 71     meredithboyd  ...          [http://arroyo.com/, http://schultz.com/]
# 72         rachel79  ...                         [https://www.morris.info/]
# 73       kathleen01  ...                                  [http://lee.com/]
# 74         bonnie77  ...                            [http://singleton.org/]
# 75         josehall  ...  [https://www.brown.com/, http://nguyen.com/, h...
# 76          kpowell  ...  [http://miller.com/, http://camacho.com/, http...
# 77        andrewfox  ...  [https://www.king-petty.info/, https://jackson...
# 78  hernandezamanda  ...         [https://jordan.com/, http://collins.com/]
# 79        rebecca78  ...  [https://www.schultz-martinez.info/, https://j...
# 80       lopeztammy  ...  [https://young-collins.com/, http://hines.com/...
# 81          fwright  ...  [https://zhang-singh.info/, https://hudson-smi...
# 82     floydrussell  ...                              [https://garcia.com/]
# 83      ericcoleman  ...      [http://www.butler.com/, https://martin.com/]
# 84   gregorysanders  ...  [https://www.obrien-ross.com/, http://campbell...
# 85      elizabeth79  ...     [http://stewart.org/, http://www.wilson.info/]
# 86         miguel56  ...                      [http://www.brown-smith.biz/]
# 87          caustin  ...                              [http://higgins.com/]
# 88           pclark  ...  [http://www.mclaughlin.com/, http://richards.c...
#
# [89 rows x 10 columns]

# %% [markdown]
# ## Cleanup

# %%
shutil.rmtree(temp_location)
