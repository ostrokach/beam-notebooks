# %% [markdown]
# # FileBasedCache - bi-directional storage primitives for Apache Beam

# %% [markdown]
# ## Install dependencies

# %%
try:
    import google.colab
    GOOGLE_COLAB = True
except ImportError:
    GOOGLE_COLAB = False

# %%
if GOOGLE_COLAB:
    # !sudo apt-get -yqq install libsnappy-dev

# %%
if GOOGLE_COLAB:
    # !pip install -q python-snappy Faker

# %%
if GOOGLE_COLAB:
    # !pip install "git+https://github.com/ostrokach/beam.git@feature/filebasedcache#egg=apache_beam[gcp]&subdirectory=sdks/python"
# Out:
# Collecting apache_beam[gcp] from git+https://github.com/ostrokach/beam.git@feature/filebasedcache#egg=apache_beam[gcp]&subdirectory=sdks/python
#   Cloning https://github.com/ostrokach/beam.git (to revision feature/filebasedcache) to /tmp/pip-install-UTZ8Wm/apache-beam
#   Running command git clone -q https://github.com/ostrokach/beam.git /tmp/pip-install-UTZ8Wm/apache-beam
#   Running command git checkout -b feature/filebasedcache --track origin/feature/filebasedcache
#   Switched to a new branch 'feature/filebasedcache'
#   Branch 'feature/filebasedcache' set up to track remote branch 'feature/filebasedcache' from 'origin'.
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.7)
# Requirement already satisfied: dill<0.2.10,>=0.2.9 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.2.9)
# Collecting fastavro<0.22,>=0.21.4 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/15/e3/5956c75f68906b119191ef30d9acff661b422cf918a29a03ee0c3ba774be/fastavro-0.21.24-cp27-cp27mu-manylinux1_x86_64.whl
# Requirement already satisfied: future<1.0.0,>=0.16.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.16.0)
# Requirement already satisfied: grpcio<2,>=1.8 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (1.15.0)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/a0/a5/1433f90ac909e259c5fd38d75d8b730be93e40cf44a0d0f5ae2742aa1d7c/hdfs-2.5.7-py2-none-any.whl
# Requirement already satisfied: httplib2<=0.12.0,>=0.8 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.11.3)
# Requirement already satisfied: mock<3.0.0,>=1.0.1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (2.0.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.8.0)
# Collecting oauth2client<4,>=2.0.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/c0/7b/bc893e35d6ca46a72faa4b9eaac25c687ce60e1fbe978993fe2de1b0ff0d/oauth2client-3.0.0.tar.gz
# Requirement already satisfied: protobuf<4,>=3.5.0.post1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.7.1)
# Collecting pydot<1.3,>=1.2.0 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/c3/f1/e61d6dfe6c1768ed2529761a68f70939e2569da043e9f15a8d84bf56cadf/pydot-1.2.4.tar.gz
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (2018.9)
# Requirement already satisfied: pyyaml<4.0.0,>=3.12 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.13)
# Collecting avro<2.0.0,>=1.8.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/5e/cd/6e79070c42215fa7dc6c338fe82002aabdacf180d8e4d3b921ff0f8462a1/avro-1.9.0.tar.gz
# Requirement already satisfied: futures<4.0.0,>=3.2.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.2.0)
# Collecting pyvcf<0.7.0,>=0.6.8 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/20/b6/36bfb1760f6983788d916096193fc14c83cce512c7787c93380e09458c09/PyVCF-0.6.8.tar.gz
# Requirement already satisfied: typing<3.7.0,>=3.6.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.6.6)
# Requirement already satisfied: pyarrow<0.14.0,>=0.11.1 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (0.13.0)
# Requirement already satisfied: cachetools<4,>=3.1.0 in /usr/local/lib/python2.7/dist-packages (from apache_beam[gcp]) (3.1.1)
# Collecting google-apitools<0.5.29,>=0.5.28 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/07/5e/3e04cb66f5ced9267a854184bb09863d85d199646ea8480fee26b4313a00/google_apitools-0.5.28-py2-none-any.whl
# Collecting google-cloud-datastore<1.8.0,>=1.7.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/d0/aa/29cbcf8cf7d08ce2d55b9dce858f7c632b434cb6451bed17cb4275804217/google_cloud_datastore-1.7.4-py2.py3-none-any.whl
# Collecting google-cloud-pubsub<0.40.0,>=0.39.0 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/c0/9a/4455b1c1450e9b912855b58ca6eee7a27ff1e9b52e4d98c243d93256f469/google_cloud_pubsub-0.39.1-py2.py3-none-any.whl
# Collecting google-cloud-bigquery<1.7.0,>=1.6.0 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/b7/1b/2b95f2fefddbbece38110712c225bfb5649206f4056445653bd5ca4dc86d/google_cloud_bigquery-1.6.1-py2.py3-none-any.whl
# Collecting google-cloud-core<0.30.0,>=0.28.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/0c/f2/3c225e7a69cb27d283b68bff867722bd066bc1858611180197f711815ea5/google_cloud_core-0.29.1-py2.py3-none-any.whl
# Collecting google-cloud-bigtable<0.33.0,>=0.31.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/08/77/b468e209dbb0a6f614e6781f06a4894299a4c6167c2c525cc086caa7c075/google_cloud_bigtable-0.32.2-py2.py3-none-any.whl
# Collecting proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/2a/1f/4124f15e1132a2eeeaf616d825990bb1d395b4c2c37362654ea5cd89bb42/proto-google-cloud-datastore-v1-0.90.4.tar.gz
# Collecting googledatastore<7.1,>=7.0.1 (from apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/3a/cf/5d90efdb2a513d5c02ba0675eefb246250b67a6ec81de610ac94d47cf1ca/googledatastore-7.0.2.tar.gz
# Requirement already satisfied: enum34>=1.0.4 in /usr/local/lib/python2.7/dist-packages (from grpcio<2,>=1.8->apache_beam[gcp]) (1.1.6)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python2.7/dist-packages (from grpcio<2,>=1.8->apache_beam[gcp]) (1.12.0)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp])
#   Downloading https://files.pythonhosted.org/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python2.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2.21.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock<3.0.0,>=1.0.1->apache_beam[gcp]) (1.0.2)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock<3.0.0,>=1.0.1->apache_beam[gcp]) (5.2.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (0.4.5)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (0.2.5)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python2.7/dist-packages (from oauth2client<4,>=2.0.1->apache_beam[gcp]) (4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf<4,>=3.5.0.post1->apache_beam[gcp]) (41.0.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python2.7/dist-packages (from pydot<1.3,>=1.2.0->apache_beam[gcp]) (2.4.0)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python2.7/dist-packages (from pyarrow<0.14.0,>=0.11.1->apache_beam[gcp]) (1.16.4)
# Collecting fasteners>=0.14 (from google-apitools<0.5.29,>=0.5.28->apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/18/bd/55eb2d6397b9c0e263af9d091ebdb756b15756029b3cededf6461481bc63/fasteners-0.15-py2.py3-none-any.whl
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.6.0 in /usr/local/lib/python2.7/dist-packages (from google-cloud-datastore<1.8.0,>=1.7.1->apache_beam[gcp]) (1.11.1)
# Collecting grpc-google-iam-v1<0.12dev,>=0.11.4 (from google-cloud-pubsub<0.40.0,>=0.39.0->apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/9b/28/f26f67381cb23e81271b8d66c00a846ad9d25a909ae1ae1df8222fad2744/grpc-google-iam-v1-0.11.4.tar.gz
# Requirement already satisfied: google-resumable-media>=0.2.1 in /usr/local/lib/python2.7/dist-packages (from google-cloud-bigquery<1.7.0,>=1.6.0->apache_beam[gcp]) (0.3.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.2 in /usr/local/lib/python2.7/dist-packages (from proto-google-cloud-datastore-v1<=0.90.4,>=0.90.0->apache_beam[gcp]) (1.6.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (2.8)
# Collecting monotonic>=0.1 (from fasteners>=0.14->google-apitools<0.5.29,>=0.5.28->apache_beam[gcp])
#   Using cached https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in /usr/local/lib/python2.7/dist-packages (from google-api-core[grpc]<2.0.0dev,>=1.6.0->google-cloud-datastore<1.8.0,>=1.7.1->apache_beam[gcp]) (1.4.2)
# Building wheels for collected packages: apache-beam, oauth2client, pydot, avro, pyvcf, proto-google-cloud-datastore-v1, googledatastore, docopt, grpc-google-iam-v1
#   Building wheel for apache-beam (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-Ogy8q0/wheels/7b/f1/05/c08b45f15562833a8aeaab50023d4c753669e750bec23555d7
#   Building wheel for oauth2client (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/48/f7/87/b932f09c6335dbcf45d916937105a372ab14f353a9ca431d7d
#   Building wheel for pydot (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/6a/a5/14/25541ebcdeaf97a37b6d05c7ff15f5bd20f5e91b99d313e5b4
#   Building wheel for avro (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/44/75/8b/415a2d3017d77b93741e72b755760c967c5e10445d2a6c2daf
#   Building wheel for pyvcf (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/81/91/41/3272543c0b9c61da9c525f24ee35bae6fe8f60d4858c66805d
#   Building wheel for proto-google-cloud-datastore-v1 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/bd/ce/33/8b769968db3761c42c7a91d8a0dbbafc50acfa0750866c8abd
#   Building wheel for googledatastore (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/09/61/a5/7e8f4442b3c3d406ee9eb6c06e1ecbe5625f62f8cb19c08f5b
#   Building wheel for docopt (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/9b/04/dd/7daf4150b6d9b12949298737de9431a324d4b797ffd63f526e
#   Building wheel for grpc-google-iam-v1 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/b6/c6/31/c20321a5a3fde456fc375b7c2814135e6e98bc0d74c40239d9
# Successfully built apache-beam oauth2client pydot avro pyvcf proto-google-cloud-datastore-v1 googledatastore docopt grpc-google-iam-v1
# ERROR: google-cloud-storage 1.16.1 has requirement google-cloud-core<2.0dev,>=1.0.0, but you'll have google-cloud-core 0.29.1 which is incompatible.
# ERROR: google-cloud-translate 1.5.0 has requirement google-cloud-core<2.0dev,>=1.0.0, but you'll have google-cloud-core 0.29.1 which is incompatible.
# Installing collected packages: fastavro, docopt, hdfs, oauth2client, pydot, avro, pyvcf, monotonic, fasteners, google-apitools, google-cloud-core, google-cloud-datastore, grpc-google-iam-v1, google-cloud-pubsub, google-cloud-bigquery, google-cloud-bigtable, proto-google-cloud-datastore-v1, googledatastore, apache-beam
#   Found existing installation: oauth2client 4.1.3
#     Uninstalling oauth2client-4.1.3:
#       Successfully uninstalled oauth2client-4.1.3
#   Found existing installation: pydot 1.3.0
#     Uninstalling pydot-1.3.0:
#       Successfully uninstalled pydot-1.3.0
#   Found existing installation: google-cloud-core 1.0.2
#     Uninstalling google-cloud-core-1.0.2:
#       Successfully uninstalled google-cloud-core-1.0.2
#   Found existing installation: google-cloud-datastore 1.8.0
#     Uninstalling google-cloud-datastore-1.8.0:
#       Successfully uninstalled google-cloud-datastore-1.8.0
#   Found existing installation: google-cloud-bigquery 1.14.0
#     Uninstalling google-cloud-bigquery-1.14.0:
#       Successfully uninstalled google-cloud-bigquery-1.14.0
# Successfully installed apache-beam-2.15.0.dev0 avro-1.9.0 docopt-0.6.2 fastavro-0.21.24 fasteners-0.15 google-apitools-0.5.28 google-cloud-bigquery-1.6.1 google-cloud-bigtable-0.32.2 google-cloud-core-0.29.1 google-cloud-datastore-1.7.4 google-cloud-pubsub-0.39.1 googledatastore-7.0.2 grpc-google-iam-v1-0.11.4 hdfs-2.5.7 monotonic-1.5 oauth2client-3.0.0 proto-google-cloud-datastore-v1-0.90.4 pydot-1.2.4 pyvcf-0.6.8

# %% [markdown]
# ## Imports

# %%
import copy
import itertools
import logging
import os
import tempfile
import uuid
import pickle

import apache_beam as beam
import fastavro
import numpy as np
import pandas as pd
import tqdm
from apache_beam.io.filesystems import FileSystems
from apache_beam.options.pipeline_options import (GoogleCloudOptions,
                                                  PipelineOptions)
from apache_beam.runners.direct.direct_runner import BundleBasedDirectRunner
from apache_beam.runners.interactive import caching
from apache_beam.transforms.ptransform import ptransform_fn
from faker import Faker

# %% [markdown]
# ## Parameters

# %%
temp_location = tempfile.mkdtemp(prefix="beam-dev-")

cache_location = tempfile.mkdtemp(dir=temp_location, prefix="cache-")

temp_location, cache_location
# Out:
# ('/tmp/beam-dev-2uKg6P', '/tmp/beam-dev-2uKg6P/cache-LUZJ3t')

# %%
options = PipelineOptions(runner="direct", temp_location=temp_location)
options.display_data()
# Out:
# WARNING:root:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-f47d2d3c-7411-4c00-b5b3-8d0a29d8d2cc.json']
# {'runner': 'direct', 'temp_location': '/tmp/beam-dev-2uKg6P'}

# %%
raise Exception("breakpoint")
# Out:
# ExceptionTraceback (most recent call last)
# <ipython-input-8-07926c403018> in <module>()
# ----> 1 raise Exception("breakpoint")
#
# Exception: breakpoint

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Generate a dataset of fake people profiles

# %%
try:
    with open("fake_people.pkl", "rb") as f:
        fake_people = pickle.load(f)
except IOError:
    fake = Faker(42)
    fake_people = [fake.profile(fields=None, sex=None) for _ in tqdm.tqdm_notebook(range(10000))]
    with open("fake_people.pkl", "wb") as f:
        pickle.dump(fake_people,f )

# %%
fake_people[0]

# %% [markdown]
# ## Analyse data

# %% [markdown]
# ### Create a PCollection cache
#
# Convert the generated dataset into a `PCollection` which can be accessed from within a Beam pipeline.

# %%
input_cache = caching.SafeTextBasedCache(FileSystems.join(cache_location, "fake_people"), if_exists="overwrite")
input_cache.write(fake_people)

# %%
next(input_cache.read())

# %% [markdown]
# ### Validate the PCollection cache

# %%
# Make sure we have 10_000 fake profiles, as expected
temp = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.combiners.Count.Globally()
        | temp.writer()
    )

assert next(temp.read()) == 10000

# %% [markdown]
# ### Select people with duplicate usernames

# %%
# Make sure every username is distinct
temp = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | "Extract username" >> beam.WithKeys(lambda e: e["username"])
        | "Group people by username" >> beam.GroupByKey(lambda e: e)
        | beam.Values()
        | "Select groups with at least two people" >> beam.Filter(lambda vs: len(vs) >= 2)
        | "Ungroup" >> beam.FlatMap(lambda gp: [e for e in gp])
        | temp.writer()
    )

# %%
pd.DataFrame(temp.read()).sort_values("username")

# %% [markdown]
# ### Find most popular occupations

# %% [markdown]
# Select top 10 most popular occupations in the `> 30` age group.

# %%
def calculate_age(birthdate):
    import datetime
    td = datetime.date.today() - birthdate
    return int(round(td.days // 365.25))

def add_age_colum(element):
    element["age"] = calculate_age(element["birthdate"])
    return element

# %%
most_popular_occupations = caching.TFRecordBasedCache(
    FileSystems.join(cache_location, "most_popular_occupations"), if_exists="overwrite"
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(add_age_colum)
        | beam.Filter(lambda e: e["age"] > 30)
        | beam.Map(lambda e: (e["job"], e))
        | beam.combiners.Count.PerKey()
        | beam.combiners.Top.Of(10, key=lambda x: x[1])
        | most_popular_occupations.writer()
    )

# %%
next(most_popular_occupations.read())

# %% [markdown]
# ## Process and export data

# %%
def normalize_data(element):
    return {
        "username": element["username"],
        "first_name": element["name"].split()[0],
        "last_name": " ".join(element["name"].split()[1:]),
        "mail": element["name"],
        "job": element["name"],
        "company": element["name"],
        "age": calculate_age(element["birthdate"]),
        "current_location_lat": float(element["current_location"][0]),
        "current_location_long": float(element["current_location"][1]),
        "website": element["website"] or [],
    }

normalize_data(element)

# %%
avro_schema = fastavro.parse_schema({
    "namespace": "example.avro",
    "name": "User",
    "type": "record",
    "fields": [
        {"name": "username", "type": "string"},
        {"name": "first_name", "type": "string"},
        {"name": "last_name", "type": "string"},
        {"name": "mail", "type": "string"},
        {"name": "job", "type": "string"},
        {"name": "company", "type": "string"},
        {"name": "age", "type": "int"},
        {"name": "current_location_lat", "type": "double"},
        {"name": "current_location_long", "type": "double"},
        {"name": "website", "type": {"type": "array", "items": "string"}},
    ],
})
avro_schema

# %%
output = caching.AvroBasedCache(
    FileSystems.join(cache_location, "temp"), if_exists="overwrite", schema=avro_schema,
    use_fastavro=True,
)

with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(normalize_data)
        | output.writer()
    )

# %%
next(output.read())

# %% [markdown]
# ## Write SQL queries against the result

# %% [markdown]
# ### Google Cloud

# %% [markdown]
# ## Export data to Google Cloud

# %%
#@title Google Cloud Project Info { display-mode: "form" }
project_id = "asdfdsf" #@param {type:"string"}
gcs_temp_location = "" #@param {type:"string"}

# %%
from google.colab import auth
auth.authenticate_user()

# %%
gcs_output = caching.AvroBasedCache(
    FileSystems.join(gcs_temp_location, "filebasedcache-output"), if_exists="overwrite",
    schema=avro_schema, use_fastavro=True)

gcs_output.write(output.read())

# %%
next(gcs_output.read())

# %% [markdown]
# ### Query data using BigQuery

# %%
from google.cloud import bigquery

# %%
options = PipelineOptions(runner="direct", temp_location=gc_temp_location, staging_location=gsc_temp_location, project=project_id)
options.display_data()

# %%
FileSystems.mkdirs(gsc_temp_location)
FileSystems.mkdirs(FileSystems.join(gsc_temp_location, "filebasedcache-demo"))

# %%
gcs_output = caching.AvroBasedCache(
    FileSystems.join(gcs_temp_location), if_exists="overwrite",
    schema=avro_schema, use_fastavro=True)

# gce_output.write(output.read())


with beam.Pipeline(options=options) as p:
    _ = (
        p
        | input_cache.reader()
        | beam.Map(normalize_data)
        | output.writer()
    )

# %%
gcs_output._existing_file_paths()

# %%
# Configure the external data source and query job
table_id = 'fake_people'
external_config = bigquery.ExternalConfig('AVRO')
external_config.source_uris = gcs_output._existing_file_paths()

# external_config.schema = [
#     bigquery.SchemaField('name', 'STRING'),
#     bigquery.SchemaField('post_abbr', 'STRING')
# ]
# external_config.options.skip_leading_rows = 1  # optionally skip header row

# %%
external_config.to_api_repr()

# %%
client = bigquery.Client(project=project_id)

# %%
# Example query to find states starting with 'W'
sql_query = """
SELECT *
FROM `{table_id}`
WHERE AGE = (
    SELECT MAX(age)
    FROM `{table_id}`
)
""".format(table_id=table_id)

job_config = bigquery.QueryJobConfig()
job_config.table_definitions = {table_id: external_config}

query_job = client.query(sql_query, job_config=job_config)

# %%
query_job.to_dataframe()

# %% [markdown]
# ## Cleanup

# %%
shutil.rmtree(temp_location)
